# %%
import pandas as pd

# %%
ass = pd.read_csv('assignment.csv')

# %%
ass
# Out:
#      Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# ...

# %% [markdown]
# ## Tasks:
# >**Rename all the column name to lowercase**
# >
# >**Drop irrelevants columns**
# >
# >**Remove the nulls in all columns**
# >
# >**Rename columns names**
# >
# >**Remove and replace country column that is abbreviated**
# >
# >**Convert income column from string to integer(remove the dollar sign)**
# >
# >**Remove non digit values from the income column**
# >
# >**Format the release year date to be consistent**
# >
# >**Remove all leading and trailing spaces**
# >
# >**Select only the first movie genre**

# %% [markdown]
# #### To rename all the column name to lowercase

# %%
ass.columns = ass.columns.str.lower()

# %%
ass
# Out:
#      unnamed: 0 imbd title id               original titlê  release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          genrë¨ duration       country content rating  \
# ...

# %% [markdown]
# #### To drop some unwanted columns

# %%
ass=ass.drop(['unnamed: 0','unnamed: 8',' votes '], axis=1)

# %%
ass
# Out:
#     imbd title id               original titlê  release year  \
# 0       tt0111161     The Shawshank Redemption    1995-02-10
# 1       tt0068646                The Godfather    09 21 1972
# 2       tt0468569              The Dark Knight   23 -07-2008
# 3       tt0071562       The Godfather: Part II    1975-09-25
# 4       tt0110912                 Pulp Fiction    1994-10-28
# ..            ...                          ...           ...
# 96      tt0070735                    The Sting    1974-03-21
# 97      tt0082096                     Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          genrë¨ duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %% [markdown]
# #### To rename columns

# %%
ass.rename(columns={'imbd title id':'imdb id'},inplace=True)

# %%
ass.rename(columns={'original titlê':'movie title'},inplace=True)

# %%
ass.rename(columns={'genrë¨':'genre'},inplace=True)

# %%
ass.rename(columns={'score':'imdb rating'},inplace=True)

# %%
ass
# Out:
#        imdb id                  movie title  release year  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10
# 1    tt0068646                The Godfather    09 21 1972
# 2    tt0468569              The Dark Knight   23 -07-2008
# 3    tt0071562       The Godfather: Part II    1975-09-25
# 4    tt0110912                 Pulp Fiction    1994-10-28
# ..         ...                          ...           ...
# 96   tt0070735                    The Sting    1974-03-21
# 97   tt0082096                     Das Boot    1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100  tt0045152          Singin' in the Rain    1953-02-05
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
ass.country
# Out:
# 0               USA
# 1               USA
# 2                US
# 3               USA
# 4               USA
#            ...
# 96              USA
# 97     West Germany
# 98            Italy
# 99             Iran
# 100             USA
# Name: country, Length: 101, dtype: object

# %%
ass
# Out:
#        imdb id                  movie title  release year  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10
# 1    tt0068646                The Godfather    09 21 1972
# 2    tt0468569              The Dark Knight   23 -07-2008
# 3    tt0071562       The Godfather: Part II    1975-09-25
# 4    tt0110912                 Pulp Fiction    1994-10-28
# ..         ...                          ...           ...
# 96   tt0070735                    The Sting    1974-03-21
# 97   tt0082096                     Das Boot    1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100  tt0045152          Singin' in the Rain    1953-02-05
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %% [markdown]
# #### To rename the abbreviated values in the 'country' column

# %%
ass.iloc[2,7]='USA'

# %%
ass.iloc[2,5]= 'USA'

# %%
ass.iloc[4,4]= 154

# %% [markdown]
#  >##### The Movie,'Pulp Fiction' had a duration of 2 hours and 34 minutes

# %%
ass
# Out:
#        imdb id                  movie title  release year  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10
# 1    tt0068646                The Godfather    09 21 1972
# 2    tt0468569              The Dark Knight   23 -07-2008
# 3    tt0071562       The Godfather: Part II    1975-09-25
# 4    tt0110912                 Pulp Fiction    1994-10-28
# ..         ...                          ...           ...
# 96   tt0070735                    The Sting    1974-03-21
# 97   tt0082096                     Das Boot    1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100  tt0045152          Singin' in the Rain    1953-02-05
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
ass.country
# Out:
# 0               USA
# 1               USA
# 2               USA
# 3               USA
# 4               USA
#            ...
# 96              USA
# 97     West Germany
# 98            Italy
# 99             Iran
# 100             USA
# Name: country, Length: 101, dtype: object

# %%
ass['country'].head(50)
# Out:
# 0             USA
# 1             USA
# 2             USA
# 3             USA
# 4             USA
# 5     New Zealand
# 6             USA
# 7             USA
# 8             USA
# 9              UK
# 10            USA
# 11    New Zesland
# 12          Italy
# 13            NaN
# 14            USA
# 15     New Zeland
# 16            USA
# 17            USA
# 18            USA
# 19            USA
# 20            USA
# 21            USA
# 22            USA
# 23            USA
# 24            US.
# 25         Brazil
# 26          Japan
# 27         Italy1
# 28    South Korea
# 29            USA
# 30          Japan
# 31            USA
# 32            USA
# 33             UK
# 34            USA
# 35            USA
# 36         France
# 37            USA
# 38            USA
# 39            USA
# 40            USA
# 41         France
# 42             UK
# 43            USA
# 44            USA
# 45            USA
# 46          Italy
# 47          Japan
# 48          Italy
# 49            USA
# ...

# %%
ass.loc[[24,25,27], 'country']=['USA','Brazil','Italy']

# %%
ass['country'].head(50)
# Out:
# 0             USA
# 1             USA
# 2             USA
# 3             USA
# 4             USA
# 5     New Zealand
# 6             USA
# 7             USA
# 8             USA
# 9              UK
# 10            USA
# 11    New Zesland
# 12          Italy
# 13            NaN
# 14            USA
# 15     New Zeland
# 16            USA
# 17            USA
# 18            USA
# 19            USA
# 20            USA
# 21            USA
# 22            USA
# 23            USA
# 24            USA
# 25         Brazil
# 26          Japan
# 27          Italy
# 28    South Korea
# 29            USA
# 30          Japan
# 31            USA
# 32            USA
# 33             UK
# 34            USA
# 35            USA
# 36         France
# 37            USA
# 38            USA
# 39            USA
# 40            USA
# 41         France
# 42             UK
# 43            USA
# 44            USA
# 45            USA
# 46          Italy
# 47          Japan
# 48          Italy
# 49            USA
# ...

# %%
ass.loc[50:100, 'country']
# Out:
# 50               UK
# 51              USA
# 52              USA
# 53              USA
# 54               UK
# 55              USA
# 56              USA
# 57               UK
# 58              USA
# 59              USA
# 60      South Korea
# 61               UK
# 62              USA
# 63              USA
# 64          Germany
# 65              USA
# 66            India
# 67            Japan
# 68              USA
# 69              USA
# 70              USA
# 71          Germany
# 72              USA
# 73              USA
# 74              USA
# 75              USA
# 76              USA
# 77              USA
# 78              USA
# 79               UK
# 80              USA
# 81               UK
# 82              USA
# 83              USA
# 84              USA
# 85           France
# 86               UK
# 87              USA
# 88               UK
# 89              USA
# 90              USA
# 91              USA
# 92              USA
# 93              USA
# 94          Denmark
# ...

# %% [markdown]
# >#### Country column has been cleaned

# %%
ass
# Out:
#        imdb id                  movie title  release year  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10
# 1    tt0068646                The Godfather    09 21 1972
# 2    tt0468569              The Dark Knight   23 -07-2008
# 3    tt0071562       The Godfather: Part II    1975-09-25
# 4    tt0110912                 Pulp Fiction    1994-10-28
# ..         ...                          ...           ...
# 96   tt0070735                    The Sting    1974-03-21
# 97   tt0082096                     Das Boot    1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100  tt0045152          Singin' in the Rain    1953-02-05
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
ass
# Out:
#        imdb id                  movie title  release year  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10
# 1    tt0068646                The Godfather    09 21 1972
# 2    tt0468569              The Dark Knight   23 -07-2008
# 3    tt0071562       The Godfather: Part II    1975-09-25
# 4    tt0110912                 Pulp Fiction    1994-10-28
# ..         ...                          ...           ...
# 96   tt0070735                    The Sting    1974-03-21
# 97   tt0082096                     Das Boot    1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100  tt0045152          Singin' in the Rain    1953-02-05
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
ass.income
# Out:
# 0         $ 28815245
# 1        $ 246120974
# 2       $ 1005455211
# 3      $ 4o8,035,783
# 4        $ 222831817
#            ...
# 96       $ 156000000
# 97        $ 11487676
# 98        $ 15000000
# 99        $ 22926076
# 100        $ 1864182
# Name: income, Length: 101, dtype: object

# %% [markdown]
# #### To remove the Dollar sign from the values of the 'income' column

# %%
ass.income.str.split('$',expand=True)
# Out:
#     0              1
# 0           28815245
# 1          246120974
# 2         1005455211
# 3        4o8,035,783
# 4          222831817
# ..  ..           ...
# 96         156000000
# 97          11487676
# 98          15000000
# 99          22926076
# 100          1864182
#
# [101 rows x 2 columns]

# %%
ass.income
# Out:
# 0         $ 28815245
# 1        $ 246120974
# 2       $ 1005455211
# 3      $ 4o8,035,783
# 4        $ 222831817
#            ...
# 96       $ 156000000
# 97        $ 11487676
# 98        $ 15000000
# 99        $ 22926076
# 100        $ 1864182
# Name: income, Length: 101, dtype: object

# %% [markdown]
# #### To remove alphabets from the values of the income column

# %%
ass['income'] = ass['income'].str.replace('[a-zA-Z,]','',regex=True)

# %%
ass['income']
# Out:
# 0        $ 28815245
# 1       $ 246120974
# 2      $ 1005455211
# 3        $ 48035783
# 4       $ 222831817
#            ...
# 96      $ 156000000
# 97       $ 11487676
# 98       $ 15000000
# 99       $ 22926076
# 100       $ 1864182
# Name: income, Length: 101, dtype: object

# %%
type(ass['income'])
# Out:
# pandas.core.series.Series

# %%
ass['income'].head(50)
# Out:
# 0       $ 28815245
# 1      $ 246120974
# 2     $ 1005455211
# 3       $ 48035783
# 4      $ 222831817
# 5     $ 1142271098
# 6      $ 322287794
# 7            $ 576
# 8      $ 869784991
# 9      $ 101218804
# 10     $ 678229452
# 11     $ 887934303
# 12      $ 25252481
# 13             NaN
# 14     $ 465718588
# 15     $ 951227416
# 16     $ 549265501
# 17      $ 46879633
# 18     $ 108997629
# 19     $ 696742056
# 20     $ 327333559
# 21     $ 272753884
# 22     $ 775768912
# 23     $ 482349603
# 24     $ 286801374
# 25      $ 30680793
# 26     $ 355467056
# 27     $ 230098753
# 28     $ 257604912
# 29       $ 6130720
# 30        $ 322773
# 31     $ 465361176
# 32     $ 291465034
# 33     $ 109676311
# 34     $ 388774684
# 35      $ 23875127
# 36      $ 19552639
# 37     $ 520884847
# 38      $ 23341568
# 39     $ 968511805
# 40    $ 1074251311
# 41     $ 426588510
# 42     $ 120072577
# 43      $ 48983260
# 44      $ 32008644
# 45       $ 4374761
# 46        $ 112911
# ...

# %%
ass.loc[50:100, 'income']
# Out:
# 50     $ 1081133191
# 51      $ 425368238
# 52       $ 39970386
# 53      $ 521311860
# 54       $ 46520613
# 55      $ 390133212
# 56     $ 2048359754
# 57      $ 108110316
# 58     $ 2797800564
# 59       $ 91968688
# 60       $ 15002116
# 61        $ 9443876
# 62       $ 37032034
# 63      $ 807083670
# 64       $ 77356942
# 65      $ 375540831
# 66       $ 60262836
# 67      $ 169785629
# 68        $ 5472914
# 69         $ 969879
# 70         $ 299645
# 71      $ 321455689
# 72      $ 356296601
# 73      $ 213216216
# 74      $ 475347111
# 75        $ 2889963
# 76       $ 74036715
# 77      $ 404265438
# 78      $ 225933435
# 79       $ 83557872
# 80        $ 7390108
# 81       $ 26903440
# 82     $ 1066969703
# 83       $ 66023585
# 84       $ 28441292
# 85      $ 173924742
# 86       $ 46357676
# 87      $ 131384634
# 88       $ 68989547
# 89        $ 1594107
# 90      $ 384857224
# 91       $ 52066791
# 92        $ 7796389
# 93          $ 73446
# 94       $ 15843274
# ...

# %% [markdown]
# #### To remove null values

# %%
ass.dropna(inplace=True)

# %%
ass.income.head(50)
# Out:
# 0       $ 28815245
# 1      $ 246120974
# 2     $ 1005455211
# 3       $ 48035783
# 4      $ 222831817
# 5     $ 1142271098
# 6      $ 322287794
# 7            $ 576
# 8      $ 869784991
# 9      $ 101218804
# 10     $ 678229452
# 11     $ 887934303
# 12      $ 25252481
# 15     $ 951227416
# 16     $ 549265501
# 17      $ 46879633
# 18     $ 108997629
# 19     $ 696742056
# 20     $ 327333559
# 21     $ 272753884
# 22     $ 775768912
# 23     $ 482349603
# 24     $ 286801374
# 25      $ 30680793
# 26     $ 355467056
# 29       $ 6130720
# 30        $ 322773
# 31     $ 465361176
# 32     $ 291465034
# 33     $ 109676311
# 34     $ 388774684
# 35      $ 23875127
# 37     $ 520884847
# 38      $ 23341568
# 39     $ 968511805
# 42     $ 120072577
# 43      $ 48983260
# 44      $ 32008644
# 45       $ 4374761
# 46        $ 112911
# 49        $ 457688
# 50    $ 1081133191
# 51     $ 425368238
# 52      $ 39970386
# 53     $ 521311860
# 54      $ 46520613
# 55     $ 390133212
# ...

# %%
ass.loc[61:100, 'income']
# Out:
# 61       $ 9443876
# 64      $ 77356942
# 67     $ 169785629
# 68       $ 5472914
# 71     $ 321455689
# 72     $ 356296601
# 73     $ 213216216
# 74     $ 475347111
# 75       $ 2889963
# 76      $ 74036715
# 77     $ 404265438
# 78     $ 225933435
# 79      $ 83557872
# 80       $ 7390108
# 82    $ 1066969703
# 83      $ 66023585
# 84      $ 28441292
# 85     $ 173924742
# 87     $ 131384634
# 88      $ 68989547
# 91      $ 52066791
# 94      $ 15843274
# 95      $ 45710874
# 96     $ 156000000
# 97      $ 11487676
# 99      $ 22926076
# Name: income, dtype: object

# %% [markdown]
# #### To replace the nulls with 0

# %%
ass.fillna(0,inplace=True)

# %% [markdown]
# #### To split the values of the 'release year' column, retaining the digits before the '-' sign

# %%
ass['release year']=ass['release year'].str.split('-', expand=True)[0]

# %%
ass[['imdb id','movie title','release year']].head(50)
# Out:
#       imdb id                                        movie title  \
# 0   tt0111161                           The Shawshank Redemption
# 1   tt0068646                                      The Godfather
# 2   tt0468569                                    The Dark Knight
# 3   tt0071562                             The Godfather: Part II
# 4   tt0110912                                       Pulp Fiction
# 5   tt0167260      The Lord of the Rings: The Return of the King
# 6   tt0108052                                   Schindler's List
# 7   tt0050083                                       12 Angry Men
# 8   tt1375666                                          Inception
# 9   tt0137523                                         Fight Club
# 10  tt0109830                                       Forrest Gump
# 11  tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12  tt0060196                    Il buono, il brutto, il cattivo
# ...

# %%
ass.iloc[1,2]=1972

# %%
ass.iloc[2,2]=2008

# %% [markdown]
# >#### The Dark knight was a 2008 movie

# %%
ass
# Out:
#       imdb id               movie title release year  \
# 0   tt0111161  The Shawshank Redemption         1995
# 1   tt0068646             The Godfather         1972
# 2   tt0468569           The Dark Knight         2008
# 3   tt0071562    The Godfather: Part II         1975
# 4   tt0110912              Pulp Fiction         1994
# ..        ...                       ...          ...
# 94  tt2106476                    Jagten         2012
# 95  tt0056172        Lawrence of Arabia         1963
# 96  tt0070735                 The Sting         1974
# 97  tt0082096                  Das Boot         1982
# 99  tt1832382   Jodaeiye Nader az Simin         2011
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# 2          Action, Crime, Drama      152           USA          PG-13
# ...

# %%
ass[['imdb id','movie title','release year']].head(50)
# Out:
#       imdb id                                        movie title  \
# 0   tt0111161                           The Shawshank Redemption
# 1   tt0068646                                      The Godfather
# 2   tt0468569                                    The Dark Knight
# 3   tt0071562                             The Godfather: Part II
# 4   tt0110912                                       Pulp Fiction
# 5   tt0167260      The Lord of the Rings: The Return of the King
# 6   tt0108052                                   Schindler's List
# 7   tt0050083                                       12 Angry Men
# 8   tt1375666                                          Inception
# 9   tt0137523                                         Fight Club
# 10  tt0109830                                       Forrest Gump
# 11  tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12  tt0060196                    Il buono, il brutto, il cattivo
# ...

# %%
ass.iloc[5,2]=2003

# %% [markdown]
# >##### The movie, "The Lord of the Rings: The Return of the King", was a 2003 movie

# %%
ass.iloc[[12,18],2]= [1966,1976]

# %%
ass.iloc[[9,15,16,38],2]= [1999,1990,1976,1942]

# %%
ass.iloc[13,2]= '2002'

# %% [markdown]
# >##### The movie,"The Lord of the Rings: The Two Towers" was a 2002 movie

# %%
ass[['imdb id','movie title','release year']].head(50)
# Out:
#       imdb id                                        movie title release year
# 0   tt0111161                           The Shawshank Redemption         1995
# 1   tt0068646                                      The Godfather         1972
# 2   tt0468569                                    The Dark Knight         2008
# 3   tt0071562                             The Godfather: Part II         1975
# 4   tt0110912                                       Pulp Fiction         1994
# 5   tt0167260      The Lord of the Rings: The Return of the King         2003
# 6   tt0108052                                   Schindler's List         1994
# 7   tt0050083                                       12 Angry Men         1957
# 8   tt1375666                                          Inception         2010
# 9   tt0137523                                         Fight Club         1999
# 10  tt0109830                                       Forrest Gump         1994
# ...

# %%
ass.iloc[61:101, [0,1,2]]
# Out:
#       imdb id                           movie title release year
# 78  tt0119217                     Good Will Hunting         1998
# 79  tt0208092                                Snatch         2001
# 80  tt0180093                   Requiem for a Dream         2000
# 82  tt0435761                           Toy Story 3         2010
# 83  tt0086250                              Scarface         1984
# 84  tt0075314                           Taxi Driver         1976
# 85  tt0211915  Le fabuleux destin d'AmÃ©lie Poulain         2002
# 87  tt0090605                                Aliens         1986
# 88  tt0062622                 2001: A Space Odyssey         1968
# 91  tt0086879                               Amadeus         1985
# 94  tt2106476                                Jagten         2012
# 95  tt0056172                    Lawrence of Arabia         1963
# 96  tt0070735                             The Sting         1974
# ...

# %% [markdown]
# >#### The 'release year' column has been cleaned and has been made consistent'

# %%
ass
# Out:
#       imdb id               movie title release year  \
# 0   tt0111161  The Shawshank Redemption         1995
# 1   tt0068646             The Godfather         1972
# 2   tt0468569           The Dark Knight         2008
# 3   tt0071562    The Godfather: Part II         1975
# 4   tt0110912              Pulp Fiction         1994
# ..        ...                       ...          ...
# 94  tt2106476                    Jagten         2012
# 95  tt0056172        Lawrence of Arabia         1963
# 96  tt0070735                 The Sting         1974
# 97  tt0082096                  Das Boot         1982
# 99  tt1832382   Jodaeiye Nader az Simin         2011
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# 2          Action, Crime, Drama      152           USA          PG-13
# ...

# %%
ass.income
# Out:
# 0       $ 28815245
# 1      $ 246120974
# 2     $ 1005455211
# 3       $ 48035783
# 4      $ 222831817
#           ...
# 94      $ 15843274
# 95      $ 45710874
# 96     $ 156000000
# 97      $ 11487676
# 99      $ 22926076
# Name: income, Length: 76, dtype: object

# %%
ass['income'].str.split('$',expand=True)[1]
# Out:
# 0        28815245
# 1       246120974
# 2      1005455211
# 3        48035783
# 4       222831817
#          ...
# 94       15843274
# 95       45710874
# 96      156000000
# 97       11487676
# 99       22926076
# Name: 1, Length: 76, dtype: object

# %%
ass['income']=ass['income'].str.split('$',expand=True)[1]

# %%
ass
# Out:
#       imdb id               movie title release year  \
# 0   tt0111161  The Shawshank Redemption         1995
# 1   tt0068646             The Godfather         1972
# 2   tt0468569           The Dark Knight         2008
# 3   tt0071562    The Godfather: Part II         1975
# 4   tt0110912              Pulp Fiction         1994
# ..        ...                       ...          ...
# 94  tt2106476                    Jagten         2012
# 95  tt0056172        Lawrence of Arabia         1963
# 96  tt0070735                 The Sting         1974
# 97  tt0082096                  Das Boot         1982
# 99  tt1832382   Jodaeiye Nader az Simin         2011
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# 2          Action, Crime, Drama      152           USA          PG-13
# ...

# %% [markdown]
# #### To make the 'income' column an integer

# %%
ass.income = ass.income.astype(int)

# %%
ass.income
# Out:
# 0       28815245
# 1      246120974
# 2     1005455211
# 3       48035783
# 4      222831817
#          ...
# 94      15843274
# 95      45710874
# 96     156000000
# 97      11487676
# 99      22926076
# Name: income, Length: 76, dtype: int32

# %% [markdown]
# #### To reassign the Dollar sign and apply the 1,000 seperator to the values of the 'income' column

# %%
ass.income = ass.income.apply(lambda x: '${:,.0f}'.format(x))

# %%
ass.income
# Out:
# 0        $28,815,245
# 1       $246,120,974
# 2     $1,005,455,211
# 3        $48,035,783
# 4       $222,831,817
#            ...
# 94       $15,843,274
# 95       $45,710,874
# 96      $156,000,000
# 97       $11,487,676
# 99       $22,926,076
# Name: income, Length: 76, dtype: object

# %%
ass
# Out:
#       imdb id               movie title release year  \
# 0   tt0111161  The Shawshank Redemption         1995
# 1   tt0068646             The Godfather         1972
# 2   tt0468569           The Dark Knight         2008
# 3   tt0071562    The Godfather: Part II         1975
# 4   tt0110912              Pulp Fiction         1994
# ..        ...                       ...          ...
# 94  tt2106476                    Jagten         2012
# 95  tt0056172        Lawrence of Arabia         1963
# 96  tt0070735                 The Sting         1974
# 97  tt0082096                  Das Boot         1982
# 99  tt1832382   Jodaeiye Nader az Simin         2011
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# 2          Action, Crime, Drama      152           USA          PG-13
# ...

# %%
ass.iloc[2,7]='Christopher Nolan'

# %%
ass
# Out:
#       imdb id               movie title release year  \
# 0   tt0111161  The Shawshank Redemption         1995
# 1   tt0068646             The Godfather         1972
# 2   tt0468569           The Dark Knight         2008
# 3   tt0071562    The Godfather: Part II         1975
# 4   tt0110912              Pulp Fiction         1994
# ..        ...                       ...          ...
# 94  tt2106476                    Jagten         2012
# 95  tt0056172        Lawrence of Arabia         1963
# 96  tt0070735                 The Sting         1974
# 97  tt0082096                  Das Boot         1982
# 99  tt1832382   Jodaeiye Nader az Simin         2011
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# 2          Action, Crime, Drama      152           USA          PG-13
# ...

# %% [markdown]
# #### To split the genre table

# %%
ass['genre'].str.split(',', expand=True)
# Out:
#             0           1          2
# 0       Drama        None       None
# 1       Crime       Drama       None
# 2      Action       Crime      Drama
# 3       Crime       Drama       None
# 4       Crime       Drama       None
# ..        ...         ...        ...
# 94      Drama        None       None
# 95  Adventure   Biography      Drama
# 96     Comedy       Crime      Drama
# 97  Adventure       Drama   Thriller
# 99      Drama        None       None
#
# [76 rows x 3 columns]

# %% [markdown]
# #### To leave the first genre behind

# %%
ass['first_genre']=ass['genre'].str.split(',', expand=True)[0]

# %%
ass
# Out:
#       imdb id               movie title release year  \
# 0   tt0111161  The Shawshank Redemption         1995
# 1   tt0068646             The Godfather         1972
# 2   tt0468569           The Dark Knight         2008
# 3   tt0071562    The Godfather: Part II         1975
# 4   tt0110912              Pulp Fiction         1994
# ..        ...                       ...          ...
# 94  tt2106476                    Jagten         2012
# 95  tt0056172        Lawrence of Arabia         1963
# 96  tt0070735                 The Sting         1974
# 97  tt0082096                  Das Boot         1982
# 99  tt1832382   Jodaeiye Nader az Simin         2011
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# 2          Action, Crime, Drama      152           USA          PG-13
# ...

# %%
ass.rename(columns={'first_genre':'genre1'}, inplace = True)

# %%
ass
# Out:
#       imdb id               movie title release year  \
# 0   tt0111161  The Shawshank Redemption         1995
# 1   tt0068646             The Godfather         1972
# 2   tt0468569           The Dark Knight         2008
# 3   tt0071562    The Godfather: Part II         1975
# 4   tt0110912              Pulp Fiction         1994
# ..        ...                       ...          ...
# 94  tt2106476                    Jagten         2012
# 95  tt0056172        Lawrence of Arabia         1963
# 96  tt0070735                 The Sting         1974
# 97  tt0082096                  Das Boot         1982
# 99  tt1832382   Jodaeiye Nader az Simin         2011
#
#                           genre duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# 2          Action, Crime, Drama      152           USA          PG-13
# ...

# %%
ass.rename(columns={'genre1':'first genre'}, inplace = True)

# %%
ass=ass.drop(['imdb rating','genre'], axis=1)

# %%
ass
# Out:
#       imdb id               movie title release year duration       country  \
# 0   tt0111161  The Shawshank Redemption         1995      142           USA
# 1   tt0068646             The Godfather         1972      175           USA
# 2   tt0468569           The Dark Knight         2008      152           USA
# 3   tt0071562    The Godfather: Part II         1975      220           USA
# 4   tt0110912              Pulp Fiction         1994      154           USA
# ..        ...                       ...          ...      ...           ...
# 94  tt2106476                    Jagten         2012      115       Denmark
# 95  tt0056172        Lawrence of Arabia         1963      228            UK
# 96  tt0070735                 The Sting         1974      129           USA
# 97  tt0082096                  Das Boot         1982      149  West Germany
# 99  tt1832382   Jodaeiye Nader az Simin         2011      123          Iran
#
# ...

# %%
ass.rename(columns={'first genre':'genre'},inplace=True)

# %%
ass
# Out:
#       imdb id               movie title release year duration       country  \
# 0   tt0111161  The Shawshank Redemption         1995      142           USA
# 1   tt0068646             The Godfather         1972      175           USA
# 2   tt0468569           The Dark Knight         2008      152           USA
# 3   tt0071562    The Godfather: Part II         1975      220           USA
# 4   tt0110912              Pulp Fiction         1994      154           USA
# ..        ...                       ...          ...      ...           ...
# 94  tt2106476                    Jagten         2012      115       Denmark
# 95  tt0056172        Lawrence of Arabia         1963      228            UK
# 96  tt0070735                 The Sting         1974      129           USA
# 97  tt0082096                  Das Boot         1982      149  West Germany
# 99  tt1832382   Jodaeiye Nader az Simin         2011      123          Iran
#
# ...

# %%
ass.to_csv('cleaned assignment.csv')
